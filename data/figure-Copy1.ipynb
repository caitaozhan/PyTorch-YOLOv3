# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.image as mpimg
import seaborn as sns
import numpy as np
from PIL import Image
plt.rcParams.update({'figure.max_open_warning': 0})

# %%
def show(idx):
    fig, axs = plt.subplots(1, 3, figsize=(30, 10))

    folder = int(idx / sample_per_label)
    folder = format(folder, '06d')
    matrix_name = str(idx % sample_per_label) + '.npy'
    target_name = str(idx % sample_per_label) + '.target.npy'
    axs[0].axis('off')
    img = np.load(f'/home/caitao/Project/dl-localization/data/{dataset}/{folder}/{matrix_name}')
    axs[0].set_title(f'Input Sensing Data - {idx}', fontsize=30)
    axs[0].imshow(img, cmap='gray')

    axs[1].axis('off')
    idx = format(idx, '06d')
    img = np.load(f'{sample_folder}/{idx}.npy')
    axs[1].set_title('Image Translation', fontsize=30)
    axs[1].imshow(img)

    axs[2].axis('off')
    img = mpimg.imread(f'../{output_folder}/{idx}.png')
    axs[2].imshow(img)
    targets = np.load(f'/home/caitao/Project/dl-localization/data/{dataset}/{folder}/{target_name}')
    title = ' '.join([f'({int(x)},{int(y)})' for x, y in targets])
    axs[2].set_title(f'Detect: {title}', fontsize=30)

    fig.tight_layout()
#     fig.show()

# %%
sample_per_label = 2
dataset = "61test"
sample_folder = 'samples3'
output_folder = 'output/sample3'

index = list(range(100))
index = index + [1008, 9179]
index = [23, 24, 31, 85, 89, 92, 9179]


for i in index:
    show(i)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
idx = 16
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
ax.axis('off')
idx = format(idx, '06d')
img = np.load(f'{sample_folder}/{idx}.npy')
ax.imshow(img)
fig.savefig('yolov3.png')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
ax.axis('off')
img = Image.open('yolov3.png')
img = img.resize((416, 416))
img = np.array(img)
img = img[:, :, :3]
grid_color = [255, 0, 0]
dx, dy = 32, 32
img[:, ::dy, :] = grid_color
img[::dx, :, :] = grid_color
ax.imshow(img)
fig.savefig('yolov3-13.png')

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
ax.axis('off')
img = Image.open('yolov3.png')
img = img.resize((416, 416))
img = np.array(img)
img = img[:, :, :3]
grid_color = [255, 0, 0]
dx, dy = 16, 16
img[:, ::dy, :] = grid_color
img[::dx, :, :] = grid_color
ax.imshow(img)
fig.savefig('yolov3-26.png')

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
ax.axis('off')
img = Image.open('yolov3.png')
img = img.resize((416, 416))
img = np.array(img)
img = img[:, :, :3]
grid_color = [255, 0, 0]
dx, dy = 8, 8
img[:, ::dy, :] = grid_color
img[::dx, :, :] = grid_color
ax.imshow(img)
fig.savefig('yolov3-52.png')

# %%
ax.imshow(img)

# %%
idx = 9179
output_folder = 'output'
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
ax.axis('off')
idx = format(idx, '06d')
# img = np.load(f'{sample_folder}/{idx}.npy')
# ax.set_title('Image Translation', fontsize=30)
# ax.imshow(img[:, :, 0], cmap='gray')
img = mpimg.imread(f'../{output_folder}/{idx}.png')
ax.imshow(img)
fig.savefig('yolov3-detect.png')

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 6))
sns.heatmap(img[:, :, 0], cmap='gray')
# Out:
# <AxesSubplot:>
